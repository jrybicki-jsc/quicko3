# %%
import pandas as pd
from tqdm import tqdm, tqdm_notebook

from tools import get_all_prefixes, get_object_list, FETCHES_BUCKET, filter_prefixes, get_jsons_from_object, get_object_list
from datetime import datetime

# %%
def generate_obj():
    _, prefixes = get_object_list(bucket_name=FETCHES_BUCKET, prefix='realtime-gzipped/')
    filtered = filter_prefixes(prefixes=prefixes, start_date=datetime(2018, 1, 1), end_date=datetime(2019,12,31))
    ret = []
    for one_prefix in tqdm_notebook(list(filtered)):
        objects, _ = get_object_list(bucket_name=FETCHES_BUCKET, prefix=one_prefix)
        ret=ret + objects
        
    return ret

# %%
def get_relevant_measurements(key, is_relevant=lambda x: x['country']=='DE' and x['parameter']=='o3'):
    measurements = get_jsons_from_object(bucket=FETCHES_BUCKET, object_name=key)
    germans = [mes for mes in measurements if is_relevant(mes)]
    return germans

# %%
# if you need a new list of objects:
obs = generate_obj()
keys = [ob['Key'] for ob in obs]
# Out:
# HBox(children=(IntProgress(value=0, max=668), HTML(value='')))

# %%
def store_keys(fname, keys):    
    with open(fname, 'w') as f:
        for key in keys:
            f.write(f'{key}\n')
            
#store_keys('./zippedkeys.dat', keys)

# %%
def read_keys(fname):
    keys = []
    with open(fname, 'r') as f:
        keys = f.readlines()
    return keys

# %%
keys = read_keys('./zippedkeys.dat')
print(f'Read {len(keys)} keys')
# Out:
# Read 83763 keys

# %%
import csv
def write_down(prefix, data):
    if len(data) == 0:
        print('Empty...')
        return
    with open(f"/tmp/ex/{prefix.replace('/','-')}.csv", 'w', encoding='utf-8') as f:
        writer = csv.writer(f, delimiter=',')
        for row in list(data):
            if not 'coordinates' in row:
                continue
            writer.writerow([row['date']['utc'], row['parameter'], row['value'], row['unit'], row['coordinates']['latitude'],row['coordinates']['longitude']])

# %%
# way of filtering relevant measurments from a given S3 object:
get_relevant_measurements(keys[0].strip(), lambda x: x['parameter']=='o3')
# Out:
# [{'date': {'utc': '2017-12-31T23:00:00.000Z',
#    'local': '2018-01-01T00:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'AD0942A',
#   'value': 57,
#   'unit': 'µg/m³',
#   'city': 'Escaldes-Engordany',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 42.5096939994651, 'longitude': 1.539138},
#   'country': 'AD',
#   'sourceName': 'EEA Andorra',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T23:00:00.000Z',
#    'local': '2018-01-01T00:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'AD0944A',
#   'value': 93,
#   'unit': 'µg/m³',
#   'city': 'Escaldes-Engordany',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 42.516943999465, 'longitude': 1.56525},
#   'country': 'AD',
#   'sourceName': 'EEA Andorra',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2018-01-01T00:00:00.000Z',
#    'local': '2018-01-01T01:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'Bjelave',
#   'value': 12,
#   'unit': 'µg/m³',
#   'city': 'Sarajevo',
#   'attribution': [{'name': 'Federalni hidrometeorološki zavod',
#     'url': 'http://www.fhmzbih.gov.ba/latinica/AKTUELNI/A-zrak.php'}],
#   'averagingPeriod': {'value': 1, 'unit': 'hours'},
#   'coordinates': {'latitude': 43.866, 'longitude': 18.423},
#   'country': 'BA',
#   'sourceName': 'Bosnia',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2018-01-01T00:00:00.000Z',
#    'local': '2018-01-01T01:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'Otoka',
#   'value': 1,
#   'unit': 'µg/m³',
#   'city': 'Sarajevo',
#   'attribution': [{'name': 'Federalni hidrometeorološki zavod',
#     'url': 'http://www.fhmzbih.gov.ba/latinica/AKTUELNI/A-zrak.php'}],
#   'averagingPeriod': {'value': 1, 'unit': 'hours'},
#   'coordinates': {'latitude': 43.848, 'longitude': 18.364},
#   'country': 'BA',
#   'sourceName': 'Bosnia',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2018-01-01T00:00:00.000Z',
#    'local': '2018-01-01T01:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'mobilna (Ilidža)',
#   'value': 1,
#   'unit': 'µg/m³',
#   'city': 'Sarajevo',
#   'attribution': [{'name': 'Federalni hidrometeorološki zavod',
#     'url': 'http://www.fhmzbih.gov.ba/latinica/AKTUELNI/A-zrak.php'}],
#   'averagingPeriod': {'value': 1, 'unit': 'hours'},
#   'coordinates': {'latitude': 43.83, 'longitude': 18.311},
#   'country': 'BA',
#   'sourceName': 'Bosnia',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2018-01-01T00:00:00.000Z',
#    'local': '2018-01-01T01:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'Ivan Sedlo',
#   'value': 62,
#   'unit': 'µg/m³',
#   'city': 'Sarajevo',
#   'attribution': [{'name': 'Federalni hidrometeorološki zavod',
#     'url': 'http://www.fhmzbih.gov.ba/latinica/AKTUELNI/A-zrak.php'}],
#   'averagingPeriod': {'value': 1, 'unit': 'hours'},
#   'coordinates': {'latitude': 43.715, 'longitude': 18.036},
#   'country': 'BA',
#   'sourceName': 'Bosnia',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2018-01-01T00:00:00.000Z',
#    'local': '2018-01-01T01:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'Harmani',
#   'value': 9,
#   'unit': 'µg/m³',
#   'city': 'Jajce',
#   'attribution': [{'name': 'Federalni hidrometeorološki zavod',
#     'url': 'http://www.fhmzbih.gov.ba/latinica/AKTUELNI/A-zrak.php'}],
#   'averagingPeriod': {'value': 1, 'unit': 'hours'},
#   'coordinates': {'latitude': 44.343, 'longitude': 17.268},
#   'country': 'BA',
#   'sourceName': 'Bosnia',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2018-01-01T00:00:00.000Z',
#    'local': '2018-01-01T01:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'Radakovo',
#   'value': 17,
#   'unit': 'µg/m³',
#   'city': 'Zenica',
#   'attribution': [{'name': 'Federalni hidrometeorološki zavod',
#     'url': 'http://www.fhmzbih.gov.ba/latinica/AKTUELNI/A-zrak.php'}],
#   'averagingPeriod': {'value': 1, 'unit': 'hours'},
#   'coordinates': {'latitude': 44.195, 'longitude': 17.932},
#   'country': 'BA',
#   'sourceName': 'Bosnia',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2018-01-01T00:00:00.000Z',
#    'local': '2018-01-01T01:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'Tetovo',
#   'value': 7,
#   'unit': 'µg/m³',
#   'city': 'Zenica',
#   'attribution': [{'name': 'Federalni hidrometeorološki zavod',
#     'url': 'http://www.fhmzbih.gov.ba/latinica/AKTUELNI/A-zrak.php'}],
#   'averagingPeriod': {'value': 1, 'unit': 'hours'},
#   'coordinates': {'latitude': 44.29, 'longitude': 17.895},
#   'country': 'BA',
#   'sourceName': 'Bosnia',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2018-01-01T00:00:00.000Z',
#    'local': '2018-01-01T01:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'Brist',
#   'value': 1,
#   'unit': 'µg/m³',
#   'city': 'Zenica',
#   'attribution': [{'name': 'Federalni hidrometeorološki zavod',
#     'url': 'http://www.fhmzbih.gov.ba/latinica/AKTUELNI/A-zrak.php'}],
#   'averagingPeriod': {'value': 1, 'unit': 'hours'},
#   'coordinates': {'latitude': 44.202, 'longitude': 17.8},
#   'country': 'BA',
#   'sourceName': 'Bosnia',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2018-01-01T00:00:00.000Z',
#    'local': '2018-01-01T01:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'Rasadnik',
#   'value': 6,
#   'unit': 'µg/m³',
#   'city': 'Goražde',
#   'attribution': [{'name': 'Federalni hidrometeorološki zavod',
#     'url': 'http://www.fhmzbih.gov.ba/latinica/AKTUELNI/A-zrak.php'}],
#   'averagingPeriod': {'value': 1, 'unit': 'hours'},
#   'coordinates': {'latitude': 43.661, 'longitude': 18.977},
#   'country': 'BA',
#   'sourceName': 'Bosnia',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T22:00:00.000Z',
#    'local': '2017-12-31T23:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CH0028A',
#   'value': 45.5607,
#   'unit': 'µg/m³',
#   'city': 'Vaud',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 46.5220101907476, 'longitude': 6.63969979320694},
#   'country': 'CH',
#   'sourceName': 'EEA Switzerland',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T22:00:00.000Z',
#    'local': '2017-12-31T23:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CH0005A',
#   'value': 50.2551,
#   'unit': 'µg/m³',
#   'city': 'Zürich',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 47.4029160301617, 'longitude': 8.61339728709878},
#   'country': 'CH',
#   'sourceName': 'EEA Switzerland',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T22:00:00.000Z',
#    'local': '2017-12-31T23:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CH0013A',
#   'value': 47.0597,
#   'unit': 'µg/m³',
#   'city': 'Zürich',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 47.3868011852188, 'longitude': 8.53980729902371},
#   'country': 'CH',
#   'sourceName': 'EEA Switzerland',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T22:00:00.000Z',
#    'local': '2017-12-31T23:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CH0011A',
#   'value': 3.0153,
#   'unit': 'µg/m³',
#   'city': 'Ticino',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 46.0111113455841, 'longitude': 8.95717356317848},
#   'country': 'CH',
#   'sourceName': 'EEA Switzerland',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T22:00:00.000Z',
#    'local': '2017-12-31T23:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CH0033A',
#   'value': 4.6673,
#   'unit': 'µg/m³',
#   'city': 'Ticino',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 46.1603950441395, 'longitude': 8.93394312993115},
#   'country': 'CH',
#   'sourceName': 'EEA Switzerland',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T22:00:00.000Z',
#    'local': '2017-12-31T23:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CH0016A',
#   'value': 45.4691,
#   'unit': 'µg/m³',
#   'city': 'Aargau',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 47.4781951524703, 'longitude': 8.36436632403517},
#   'country': 'CH',
#   'sourceName': 'EEA Switzerland',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T22:00:00.000Z',
#    'local': '2017-12-31T23:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CH0044A',
#   'value': 21.7181,
#   'unit': 'µg/m³',
#   'city': 'Zürich',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 47.438715904853, 'longitude': 8.5701164567099},
#   'country': 'CH',
#   'sourceName': 'EEA Switzerland',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T22:00:00.000Z',
#    'local': '2017-12-31T23:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CH0043A',
#   'value': 4.6829,
#   'unit': 'µg/m³',
#   'city': 'Ticino',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 46.0258957256916, 'longitude': 8.96752215525154},
#   'country': 'CH',
#   'sourceName': 'EEA Switzerland',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T22:00:00.000Z',
#    'local': '2017-12-31T23:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CH0031A',
#   'value': 30.0698,
#   'unit': 'µg/m³',
#   'city': 'Bern',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 46.9510019036189, 'longitude': 7.44087126250177},
#   'country': 'CH',
#   'sourceName': 'EEA Switzerland',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T20:00:00.000Z',
#    'local': '2017-12-31T21:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CH0004R',
#   'value': 71.9264,
#   'unit': 'µg/m³',
#   'city': 'Neuchâtel',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 47.0495154343676, 'longitude': 6.97920907168707},
#   'country': 'CH',
#   'sourceName': 'EEA Switzerland',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T21:00:00.000Z',
#    'local': '2017-12-31T22:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CH0004R',
#   'value': 64.0196,
#   'unit': 'µg/m³',
#   'city': 'Neuchâtel',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 47.0495154343676, 'longitude': 6.97920907168707},
#   'country': 'CH',
#   'sourceName': 'EEA Switzerland',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T22:00:00.000Z',
#    'local': '2017-12-31T23:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CH0004R',
#   'value': 64.0416,
#   'unit': 'µg/m³',
#   'city': 'Neuchâtel',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 47.0495154343676, 'longitude': 6.97920907168707},
#   'country': 'CH',
#   'sourceName': 'EEA Switzerland',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T22:00:00.000Z',
#    'local': '2017-12-31T23:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CH0041A',
#   'value': 35.1882,
#   'unit': 'µg/m³',
#   'city': 'Bern',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 46.9763828250552, 'longitude': 7.47871728542173},
#   'country': 'CH',
#   'sourceName': 'EEA Switzerland',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T22:00:00.000Z',
#    'local': '2017-12-31T23:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CH0002R',
#   'value': 61.324,
#   'unit': 'µg/m³',
#   'city': 'Vaud',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 46.8130974472165, 'longitude': 6.94448020280301},
#   'country': 'CH',
#   'sourceName': 'EEA Switzerland',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T22:00:00.000Z',
#    'local': '2017-12-31T23:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CH0024A',
#   'value': 2.0753,
#   'unit': 'µg/m³',
#   'city': 'Valais',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 46.1389868286334, 'longitude': 7.14832590707541},
#   'country': 'CH',
#   'sourceName': 'EEA Switzerland',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T22:00:00.000Z',
#    'local': '2017-12-31T23:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CH0051A',
#   'value': 61.4612,
#   'unit': 'µg/m³',
#   'city': 'Genève',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 46.1625727389095, 'longitude': 6.00518377542195},
#   'country': 'CH',
#   'sourceName': 'EEA Switzerland',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T22:00:00.000Z',
#    'local': '2017-12-31T23:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CH0022A',
#   'value': 28.497,
#   'unit': 'µg/m³',
#   'city': 'Lucerne',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 47.0676889994646, 'longitude': 8.300661},
#   'country': 'CH',
#   'sourceName': 'EEA Switzerland',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T22:00:00.000Z',
#    'local': '2017-12-31T23:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CH0021A',
#   'value': 52.2719,
#   'unit': 'µg/m³',
#   'city': 'Zürich',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 47.3709247660476, 'longitude': 8.5235388092283},
#   'country': 'CH',
#   'sourceName': 'EEA Switzerland',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T22:00:00.000Z',
#    'local': '2017-12-31T23:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CH0010A',
#   'value': 53.1456,
#   'unit': 'µg/m³',
#   'city': 'Zürich',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 47.3776165600282, 'longitude': 8.53041092115182},
#   'country': 'CH',
#   'sourceName': 'EEA Switzerland',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T22:00:00.000Z',
#    'local': '2017-12-31T23:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CH0003R',
#   'value': 66.1583,
#   'unit': 'µg/m³',
#   'city': 'Thurgau',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 47.479773705802, 'longitude': 8.90467601797453},
#   'country': 'CH',
#   'sourceName': 'EEA Switzerland',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T22:00:00.000Z',
#    'local': '2017-12-31T23:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CH0050A',
#   'value': 60.5632,
#   'unit': 'µg/m³',
#   'city': 'Genève',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 46.2310949338438, 'longitude': 6.07417438924233},
#   'country': 'CH',
#   'sourceName': 'EEA Switzerland',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T22:00:00.000Z',
#    'local': '2017-12-31T23:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CH0046A',
#   'value': 66.5497,
#   'unit': 'µg/m³',
#   'city': 'Genève',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 46.1956009059889, 'longitude': 6.21124831844613},
#   'country': 'CH',
#   'sourceName': 'EEA Switzerland',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T22:00:00.000Z',
#    'local': '2017-12-31T23:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CH0005R',
#   'value': 69.5926,
#   'unit': 'µg/m³',
#   'city': 'Schwyz',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 47.0673852211321, 'longitude': 8.46333371888661},
#   'country': 'CH',
#   'sourceName': 'EEA Switzerland',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T22:00:00.000Z',
#    'local': '2017-12-31T23:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CH0019A',
#   'value': 74.4257,
#   'unit': 'µg/m³',
#   'city': 'Sankt Gallen',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 47.4069895689662, 'longitude': 9.39431174673672},
#   'country': 'CH',
#   'sourceName': 'EEA Switzerland',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T22:00:00.000Z',
#    'local': '2017-12-31T23:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CH0008A',
#   'value': 41.3231,
#   'unit': 'µg/m³',
#   'city': 'Basel-Landschaft',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 47.5411183702413, 'longitude': 7.58328118449324},
#   'country': 'CH',
#   'sourceName': 'EEA Switzerland',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2018-01-01T01:00:00.000Z',
#    'local': '2017-12-31T22:00:00-03:00'},
#   'parameter': 'o3',
#   'location': 'Escuela E-10',
#   'value': 24.9,
#   'unit': 'µg/m³',
#   'city': 'Tocopilla',
#   'attribution': [{'name': 'SINCA', 'url': 'http://sinca.mma.gob.cl/'},
#    {'name': 'Electroandina S.A.'}],
#   'coordinates': {'latitude': -22.085518710314, 'longitude': -70.188682515839},
#   'country': 'CL',
#   'sourceName': 'Chile - SINCA',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T23:00:00.000Z',
#    'local': '2017-12-31T20:00:00-03:00'},
#   'parameter': 'o3',
#   'location': 'Independencia',
#   'value': 31.41,
#   'unit': 'µg/m³',
#   'city': 'Independencia',
#   'attribution': [{'name': 'SINCA', 'url': 'http://sinca.mma.gob.cl/'},
#    {'name': 'Ministerio del Medio Ambiente'}],
#   'coordinates': {'latitude': -33.422301, 'longitude': -70.651162},
#   'country': 'CL',
#   'sourceName': 'Chile - SINCA',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T23:00:00.000Z',
#    'local': '2017-12-31T20:00:00-03:00'},
#   'parameter': 'o3',
#   'location': 'La Florida',
#   'value': 30.84,
#   'unit': 'µg/m³',
#   'city': 'La Florida',
#   'attribution': [{'name': 'SINCA', 'url': 'http://sinca.mma.gob.cl/'},
#    {'name': 'Ministerio del Medio Ambiente'}],
#   'coordinates': {'latitude': -33.516630362266, 'longitude': -70.588123961971},
#   'country': 'CL',
#   'sourceName': 'Chile - SINCA',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T23:00:00.000Z',
#    'local': '2017-12-31T20:00:00-03:00'},
#   'parameter': 'o3',
#   'location': 'Las Condes',
#   'value': 33.27,
#   'unit': 'µg/m³',
#   'city': 'Las Condes',
#   'attribution': [{'name': 'SINCA', 'url': 'http://sinca.mma.gob.cl/'},
#    {'name': 'Ministerio del Medio Ambiente'}],
#   'coordinates': {'latitude': -33.37677352033, 'longitude': -70.523326784061},
#   'country': 'CL',
#   'sourceName': 'Chile - SINCA',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T23:00:00.000Z',
#    'local': '2017-12-31T20:00:00-03:00'},
#   'parameter': 'o3',
#   'location': 'Pudahuel',
#   'value': 33.28,
#   'unit': 'µg/m³',
#   'city': 'Pudahuel',
#   'attribution': [{'name': 'SINCA', 'url': 'http://sinca.mma.gob.cl/'},
#    {'name': 'Ministerio del Medio Ambiente'}],
#   'coordinates': {'latitude': -33.437811379126, 'longitude': -70.750171233135},
#   'country': 'CL',
#   'sourceName': 'Chile - SINCA',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T23:00:00.000Z',
#    'local': '2017-12-31T20:00:00-03:00'},
#   'parameter': 'o3',
#   'location': 'El Bosque',
#   'value': 31.74,
#   'unit': 'µg/m³',
#   'city': 'El Bosque',
#   'attribution': [{'name': 'SINCA', 'url': 'http://sinca.mma.gob.cl/'},
#    {'name': 'Ministerio del Medio Ambiente'}],
#   'coordinates': {'latitude': -33.547099645619, 'longitude': -70.666204101852},
#   'country': 'CL',
#   'sourceName': 'Chile - SINCA',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T23:00:00.000Z',
#    'local': '2017-12-31T20:00:00-03:00'},
#   'parameter': 'o3',
#   'location': 'Cerro Navia',
#   'value': 41.97,
#   'unit': 'µg/m³',
#   'city': 'Cerro Navia',
#   'attribution': [{'name': 'SINCA', 'url': 'http://sinca.mma.gob.cl/'},
#    {'name': 'Ministerio del Medio Ambiente'}],
#   'coordinates': {'latitude': -33.433089610143, 'longitude': -70.732147868717},
#   'country': 'CL',
#   'sourceName': 'Chile - SINCA',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T23:00:00.000Z',
#    'local': '2017-12-31T20:00:00-03:00'},
#   'parameter': 'o3',
#   'location': 'Puente Alto',
#   'value': 33.52,
#   'unit': 'µg/m³',
#   'city': 'Puente Alto',
#   'attribution': [{'name': 'SINCA', 'url': 'http://sinca.mma.gob.cl/'},
#    {'name': 'Ministerio del Medio Ambiente'}],
#   'coordinates': {'latitude': -33.591390623022, 'longitude': -70.594788},
#   'country': 'CL',
#   'sourceName': 'Chile - SINCA',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T23:00:00.000Z',
#    'local': '2017-12-31T20:00:00-03:00'},
#   'parameter': 'o3',
#   'location': 'Talagante',
#   'value': 40.46,
#   'unit': 'µg/m³',
#   'city': 'Talagante',
#   'attribution': [{'name': 'SINCA', 'url': 'http://sinca.mma.gob.cl/'},
#    {'name': 'Ministerio del Medio Ambiente'}],
#   'coordinates': {'latitude': -33.673752071375, 'longitude': -70.953064737434},
#   'country': 'CL',
#   'sourceName': 'Chile - SINCA',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T21:00:00.000Z',
#    'local': '2017-12-31T22:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CZ0UULK',
#   'value': 34.7,
#   'unit': 'µg/m³',
#   'city': 'Ústecký',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 50.6835094295933, 'longitude': 14.0412068799586},
#   'country': 'CZ',
#   'sourceName': 'EEA Czech Republic',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T21:00:00.000Z',
#    'local': '2017-12-31T22:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CZ0UMOM',
#   'value': 44.7,
#   'unit': 'µg/m³',
#   'city': 'Ústecký',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 50.5103893564267, 'longitude': 13.6452295027187},
#   'country': 'CZ',
#   'sourceName': 'EEA Czech Republic',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T21:00:00.000Z',
#    'local': '2017-12-31T22:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CZ0UTUS',
#   'value': 50.5,
#   'unit': 'µg/m³',
#   'city': 'Ústecký',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 50.3765794417562, 'longitude': 13.327585218254},
#   'country': 'CZ',
#   'sourceName': 'EEA Czech Republic',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T21:00:00.000Z',
#    'local': '2017-12-31T22:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CZ0TOVK',
#   'value': 46.3,
#   'unit': 'µg/m³',
#   'city': 'Moravskoslezský',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 49.9460043993667, 'longitude': 17.9095321564341},
#   'country': 'CZ',
#   'sourceName': 'EEA Czech Republic',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T21:00:00.000Z',
#    'local': '2017-12-31T22:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CZ0ARIE',
#   'value': 39.7,
#   'unit': 'µg/m³',
#   'city': 'Hlavní město Praha',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 50.0814873931859, 'longitude': 14.4426639804316},
#   'country': 'CZ',
#   'sourceName': 'EEA Czech Republic',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T21:00:00.000Z',
#    'local': '2017-12-31T22:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CZ0ZTNV',
#   'value': 62,
#   'unit': 'µg/m³',
#   'city': 'Zlínský',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 49.259391784668, 'longitude': 17.4105606079102},
#   'country': 'CZ',
#   'sourceName': 'EEA Czech Republic',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T21:00:00.000Z',
#    'local': '2017-12-31T22:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CZ0LLIL',
#   'value': 52.1,
#   'unit': 'µg/m³',
#   'city': 'Liberecký',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 50.7551002502441, 'longitude': 15.0699672698975},
#   'country': 'CZ',
#   'sourceName': 'EEA Czech Republic',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T21:00:00.000Z',
#    'local': '2017-12-31T22:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CZ0UDOK',
#   'value': 54.9,
#   'unit': 'µg/m³',
#   'city': 'Ústecký',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 50.458832401371, 'longitude': 14.1702049547582},
#   'country': 'CZ',
#   'sourceName': 'EEA Czech Republic',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T21:00:00.000Z',
#    'local': '2017-12-31T22:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CZ0HPLO',
#   'value': 62,
#   'unit': 'µg/m³',
#   'city': 'Královéhradecký',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 50.3502769470215, 'longitude': 16.3225002288818},
#   'country': 'CZ',
#   'sourceName': 'EEA Czech Republic',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T21:00:00.000Z',
#    'local': '2017-12-31T22:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CZ0LFRT',
#   'value': 51.9,
#   'unit': 'µg/m³',
#   'city': 'Liberecký',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 50.9406509399414, 'longitude': 15.0698165893555},
#   'country': 'CZ',
#   'sourceName': 'EEA Czech Republic',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T21:00:00.000Z',
#    'local': '2017-12-31T22:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CZ0BBDN',
#   'value': 3.6,
#   'unit': 'µg/m³',
#   'city': 'Jihomoravský',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 49.2027258665263, 'longitude': 16.6163174734156},
#   'country': 'CZ',
#   'sourceName': 'EEA Czech Republic',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T21:00:00.000Z',
#    'local': '2017-12-31T22:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CZ0EPAU',
#   'value': 48.1,
#   'unit': 'µg/m³',
#   'city': 'Pardubický',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 50.0240389213472, 'longitude': 15.763546774201},
#   'country': 'CZ',
#   'sourceName': 'EEA Czech Republic',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T21:00:00.000Z',
#    'local': '2017-12-31T22:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CZ0PPLL',
#   'value': 42.9,
#   'unit': 'µg/m³',
#   'city': 'Plzeňský',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 49.7701232212967, 'longitude': 13.3681890690962},
#   'country': 'CZ',
#   'sourceName': 'EEA Czech Republic',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T21:00:00.000Z',
#    'local': '2017-12-31T22:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CZ0ESVR',
#   'value': 58.3,
#   'unit': 'µg/m³',
#   'city': 'Pardubický',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 49.7350675472712, 'longitude': 16.0342091693062},
#   'country': 'CZ',
#   'sourceName': 'EEA Czech Republic',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T21:00:00.000Z',
#    'local': '2017-12-31T22:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CZ0ZSNV',
#   'value': 44.1,
#   'unit': 'µg/m³',
#   'city': 'Zlínský',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 49.0478238497708, 'longitude': 18.0078078485168},
#   'country': 'CZ',
#   'sourceName': 'EEA Czech Republic',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T21:00:00.000Z',
#    'local': '2017-12-31T22:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CZ0PPLV',
#   'value': 43.3,
#   'unit': 'µg/m³',
#   'city': 'Plzeňský',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 49.7686147240817, 'longitude': 13.4233456275412},
#   'country': 'CZ',
#   'sourceName': 'EEA Czech Republic',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T21:00:00.000Z',
#    'local': '2017-12-31T22:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CZ0MPRR',
#   'value': 38.5,
#   'unit': 'µg/m³',
#   'city': 'Olomoucký',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 49.451665554158, 'longitude': 17.4541761389139},
#   'country': 'CZ',
#   'sourceName': 'EEA Czech Republic',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T21:00:00.000Z',
#    'local': '2017-12-31T22:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CZ0BKUC',
#   'value': 57.9,
#   'unit': 'µg/m³',
#   'city': 'Jihomoravský',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 48.8813328738731, 'longitude': 16.0857724666146},
#   'country': 'CZ',
#   'sourceName': 'EEA Czech Republic',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T21:00:00.000Z',
#    'local': '2017-12-31T22:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CZ0UULM',
#   'value': 11.8,
#   'unit': 'µg/m³',
#   'city': 'Ústecký',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 50.661078545214, 'longitude': 14.0430933420552},
#   'country': 'CZ',
#   'sourceName': 'EEA Czech Republic',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T21:00:00.000Z',
#    'local': '2017-12-31T22:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CZ0TCER',
#   'value': 51.9,
#   'unit': 'µg/m³',
#   'city': 'Moravskoslezský',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 49.7771415694708, 'longitude': 17.54194641},
#   'country': 'CZ',
#   'sourceName': 'EEA Czech Republic',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T21:00:00.000Z',
#    'local': '2017-12-31T22:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CZ0ZZLN',
#   'value': 45.7,
#   'unit': 'µg/m³',
#   'city': 'Zlínský',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 49.2328856560366, 'longitude': 17.6671666927786},
#   'country': 'CZ',
#   'sourceName': 'EEA Czech Republic',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T21:00:00.000Z',
#    'local': '2017-12-31T22:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CZ0USNZ',
#   'value': 47.5,
#   'unit': 'µg/m³',
#   'city': 'Ústecký',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 50.7916985992017, 'longitude': 14.0870209594487},
#   'country': 'CZ',
#   'sourceName': 'EEA Czech Republic',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T21:00:00.000Z',
#    'local': '2017-12-31T22:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CZ0ULOM',
#   'value': 22.3,
#   'unit': 'µg/m³',
#   'city': 'Ústecký',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 50.5857942306629, 'longitude': 13.6734366026401},
#   'country': 'CZ',
#   'sourceName': 'EEA Czech Republic',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T21:00:00.000Z',
#    'local': '2017-12-31T22:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CZ0CTAB',
#   'value': 43.1,
#   'unit': 'µg/m³',
#   'city': 'Jihočeský',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 49.4112371227718, 'longitude': 14.6764056173595},
#   'country': 'CZ',
#   'sourceName': 'EEA Czech Republic',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T21:00:00.000Z',
#    'local': '2017-12-31T22:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CZ0JJIH',
#   'value': 43.7,
#   'unit': 'µg/m³',
#   'city': 'Vysočina',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 49.4016509339586, 'longitude': 15.6099348606165},
#   'country': 'CZ',
#   'sourceName': 'EEA Czech Republic',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T21:00:00.000Z',
#    'local': '2017-12-31T22:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CZ0ULTT',
#   'value': 51.9,
#   'unit': 'µg/m³',
#   'city': 'Ústecký',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 50.5408854846136, 'longitude': 14.1194501412054},
#   'country': 'CZ',
#   'sourceName': 'EEA Czech Republic',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T21:00:00.000Z',
#    'local': '2017-12-31T22:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CZ0SKLM',
#   'value': 61,
#   'unit': 'µg/m³',
#   'city': 'Středočeský',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 50.1438759202218, 'longitude': 14.1017533301082},
#   'country': 'CZ',
#   'sourceName': 'EEA Czech Republic',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T21:00:00.000Z',
#    'local': '2017-12-31T22:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CZ0SMBO',
#   'value': 3.4,
#   'unit': 'µg/m³',
#   'city': 'Středočeský',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 50.4286266173036, 'longitude': 14.9138303469523},
#   'country': 'CZ',
#   'sourceName': 'EEA Czech Republic',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T21:00:00.000Z',
#    'local': '2017-12-31T22:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CZ0PPLA',
#   'value': 52.9,
#   'unit': 'µg/m³',
#   'city': 'Plzeňský',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 49.7324547692273, 'longitude': 13.4023250498928},
#   'country': 'CZ',
#   'sourceName': 'EEA Czech Republic',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T21:00:00.000Z',
#    'local': '2017-12-31T22:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CZ0URVH',
#   'value': 61.8,
#   'unit': 'µg/m³',
#   'city': 'Ústecký',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 50.579862110834, 'longitude': 13.4194828718195},
#   'country': 'CZ',
#   'sourceName': 'EEA Czech Republic',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T21:00:00.000Z',
#    'local': '2017-12-31T22:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CZ0CPRA',
#   'value': 66.4,
#   'unit': 'µg/m³',
#   'city': 'Jihočeský',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 49.0160865783691, 'longitude': 14.0004444122314},
#   'country': 'CZ',
#   'sourceName': 'EEA Czech Republic',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T21:00:00.000Z',
#    'local': '2017-12-31T22:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CZ0TBKR',
#   'value': 54.1,
#   'unit': 'µg/m³',
#   'city': 'Moravskoslezský',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 49.5026209481914, 'longitude': 18.5385325183746},
#   'country': 'CZ',
#   'sourceName': 'EEA Czech Republic',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T21:00:00.000Z',
#    'local': '2017-12-31T22:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CZ0TTRO',
#   'value': 39.5,
#   'unit': 'µg/m³',
#   'city': 'Moravskoslezský',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 49.6681361323838, 'longitude': 18.6777713874131},
#   'country': 'CZ',
#   'sourceName': 'EEA Czech Republic',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T21:00:00.000Z',
#    'local': '2017-12-31T22:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CZ0JKOS',
#   'value': 64.8,
#   'unit': 'µg/m³',
#   'city': 'Vysočina',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 49.5733917733641, 'longitude': 15.0802881690996},
#   'country': 'CZ',
#   'sourceName': 'EEA Czech Republic',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T21:00:00.000Z',
#    'local': '2017-12-31T22:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CZ0BMIS',
#   'value': 57.1,
#   'unit': 'µg/m³',
#   'city': 'Jihomoravský',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 48.7917540483835, 'longitude': 16.7244746336236},
#   'country': 'CZ',
#   'sourceName': 'EEA Czech Republic',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T21:00:00.000Z',
#    'local': '2017-12-31T22:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CZ0JKMY',
#   'value': 52.9,
#   'unit': 'µg/m³',
#   'city': 'Vysočina',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 49.1501663523476, 'longitude': 15.439075293577},
#   'country': 'CZ',
#   'sourceName': 'EEA Czech Republic',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T21:00:00.000Z',
#    'local': '2017-12-31T22:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CZ0BBNY',
#   'value': 19.2,
#   'unit': 'µg/m³',
#   'city': 'Jihomoravský',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 49.1489912005135, 'longitude': 16.6961777021738},
#   'country': 'CZ',
#   'sourceName': 'EEA Czech Republic',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T21:00:00.000Z',
#    'local': '2017-12-31T22:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CZ0HKRY',
#   'value': 57.5,
#   'unit': 'µg/m³',
#   'city': 'Královéhradecký',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 50.6604521484459, 'longitude': 15.8500545360617},
#   'country': 'CZ',
#   'sourceName': 'EEA Czech Republic',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T21:00:00.000Z',
#    'local': '2017-12-31T22:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CZ0CCBD',
#   'value': 44.3,
#   'unit': 'µg/m³',
#   'city': 'Jihočeský',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 48.9843716150984, 'longitude': 14.4656608517051},
#   'country': 'CZ',
#   'sourceName': 'EEA Czech Republic',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T21:00:00.000Z',
#    'local': '2017-12-31T22:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CZ0CHVO',
#   'value': 54.7,
#   'unit': 'µg/m³',
#   'city': 'Jihočeský',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 48.7241833025926, 'longitude': 14.723387506719},
#   'country': 'CZ',
#   'sourceName': 'EEA Czech Republic',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T21:00:00.000Z',
#    'local': '2017-12-31T22:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CZ0CCHU',
#   'value': 66,
#   'unit': 'µg/m³',
#   'city': 'Jihočeský',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 49.0684269411775, 'longitude': 13.6147766145871},
#   'country': 'CZ',
#   'sourceName': 'EEA Czech Republic',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T21:00:00.000Z',
#    'local': '2017-12-31T22:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CZ0PPRM',
#   'value': 58.9,
#   'unit': 'µg/m³',
#   'city': 'Plzeňský',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 49.6695896158391, 'longitude': 12.6779236047788},
#   'country': 'CZ',
#   'sourceName': 'EEA Czech Republic',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T21:00:00.000Z',
#    'local': '2017-12-31T22:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CZ0MJES',
#   'value': 61.6,
#   'unit': 'µg/m³',
#   'city': 'Olomoucký',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 50.2422186696447, 'longitude': 17.1901612769112},
#   'country': 'CZ',
#   'sourceName': 'EEA Czech Republic',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T21:00:00.000Z',
#    'local': '2017-12-31T22:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CZ0TSTD',
#   'value': 35.1,
#   'unit': 'µg/m³',
#   'city': 'Moravskoslezský',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 49.7209568747397, 'longitude': 18.0892850447864},
#   'country': 'CZ',
#   'sourceName': 'EEA Czech Republic',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T21:00:00.000Z',
#    'local': '2017-12-31T22:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CZ0TKAR',
#   'value': 57.3,
#   'unit': 'µg/m³',
#   'city': 'Moravskoslezský',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 49.8637900033438, 'longitude': 18.5514682584659},
#   'country': 'CZ',
#   'sourceName': 'EEA Czech Republic',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T21:00:00.000Z',
#    'local': '2017-12-31T22:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CZ0TOFF',
#   'value': 43.3,
#   'unit': 'µg/m³',
#   'city': 'Moravskoslezský',
#   'attribution': [{'name': 'EEA',
#     'url': 'http://www.eea.europa.eu/themes/air/air-quality'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 1},
#   'coordinates': {'latitude': 49.8391736740214, 'longitude': 18.2633785468488},
#   'country': 'CZ',
#   'sourceName': 'EEA Czech Republic',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T21:00:00.000Z',
#    'local': '2017-12-31T22:00:00+01:00'},
#   'parameter': 'o3',
#   'location': 'CZ0AVYN',
# ...
#   'parameter': 'o3',
#   'location': 'תחנה:ניידת חיפה',
#   'value': 0.037399999999999996,
#   'unit': 'ppm',
#   'city': 'צפון הנגב',
#   'attribution': [{'name': 'Israel Ministry of Environmental Protection',
#     'url': 'http://www.svivaaqm.net/'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 0.25},
#   'coordinates': {'latitude': 31.24897, 'longitude': 35.21597},
#   'country': 'IL',
#   'sourceName': 'Israel',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T03:00:00.000Z',
#    'local': '2017-12-31T05:00:00+02:00'},
#   'parameter': 'o3',
#   'location': 'תחנה:ניידת חיפה',
#   'value': 0.0384,
#   'unit': 'ppm',
#   'city': 'צפון הנגב',
#   'attribution': [{'name': 'Israel Ministry of Environmental Protection',
#     'url': 'http://www.svivaaqm.net/'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 0.25},
#   'coordinates': {'latitude': 31.24897, 'longitude': 35.21597},
#   'country': 'IL',
#   'sourceName': 'Israel',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T03:15:00.000Z',
#    'local': '2017-12-31T05:15:00+02:00'},
#   'parameter': 'o3',
#   'location': 'תחנה:ניידת חיפה',
#   'value': 0.0394,
#   'unit': 'ppm',
#   'city': 'צפון הנגב',
#   'attribution': [{'name': 'Israel Ministry of Environmental Protection',
#     'url': 'http://www.svivaaqm.net/'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 0.25},
#   'coordinates': {'latitude': 31.24897, 'longitude': 35.21597},
#   'country': 'IL',
#   'sourceName': 'Israel',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T03:30:00.000Z',
#    'local': '2017-12-31T05:30:00+02:00'},
#   'parameter': 'o3',
#   'location': 'תחנה:ניידת חיפה',
#   'value': 0.039799999999999995,
#   'unit': 'ppm',
#   'city': 'צפון הנגב',
#   'attribution': [{'name': 'Israel Ministry of Environmental Protection',
#     'url': 'http://www.svivaaqm.net/'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 0.25},
#   'coordinates': {'latitude': 31.24897, 'longitude': 35.21597},
#   'country': 'IL',
#   'sourceName': 'Israel',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T03:45:00.000Z',
#    'local': '2017-12-31T05:45:00+02:00'},
#   'parameter': 'o3',
#   'location': 'תחנה:ניידת חיפה',
#   'value': 0.041100000000000005,
#   'unit': 'ppm',
#   'city': 'צפון הנגב',
#   'attribution': [{'name': 'Israel Ministry of Environmental Protection',
#     'url': 'http://www.svivaaqm.net/'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 0.25},
#   'coordinates': {'latitude': 31.24897, 'longitude': 35.21597},
#   'country': 'IL',
#   'sourceName': 'Israel',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T04:00:00.000Z',
#    'local': '2017-12-31T06:00:00+02:00'},
#   'parameter': 'o3',
#   'location': 'תחנה:ניידת חיפה',
#   'value': 0.0423,
#   'unit': 'ppm',
#   'city': 'צפון הנגב',
#   'attribution': [{'name': 'Israel Ministry of Environmental Protection',
#     'url': 'http://www.svivaaqm.net/'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 0.25},
#   'coordinates': {'latitude': 31.24897, 'longitude': 35.21597},
#   'country': 'IL',
#   'sourceName': 'Israel',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T04:15:00.000Z',
#    'local': '2017-12-31T06:15:00+02:00'},
#   'parameter': 'o3',
#   'location': 'תחנה:ניידת חיפה',
#   'value': 0.040799999999999996,
#   'unit': 'ppm',
#   'city': 'צפון הנגב',
#   'attribution': [{'name': 'Israel Ministry of Environmental Protection',
#     'url': 'http://www.svivaaqm.net/'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 0.25},
#   'coordinates': {'latitude': 31.24897, 'longitude': 35.21597},
#   'country': 'IL',
#   'sourceName': 'Israel',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T04:30:00.000Z',
#    'local': '2017-12-31T06:30:00+02:00'},
#   'parameter': 'o3',
#   'location': 'תחנה:ניידת חיפה',
#   'value': 0.038799999999999994,
#   'unit': 'ppm',
#   'city': 'צפון הנגב',
#   'attribution': [{'name': 'Israel Ministry of Environmental Protection',
#     'url': 'http://www.svivaaqm.net/'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 0.25},
#   'coordinates': {'latitude': 31.24897, 'longitude': 35.21597},
#   'country': 'IL',
#   'sourceName': 'Israel',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T04:45:00.000Z',
#    'local': '2017-12-31T06:45:00+02:00'},
#   'parameter': 'o3',
#   'location': 'תחנה:ניידת חיפה',
#   'value': 0.0376,
#   'unit': 'ppm',
#   'city': 'צפון הנגב',
#   'attribution': [{'name': 'Israel Ministry of Environmental Protection',
#     'url': 'http://www.svivaaqm.net/'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 0.25},
#   'coordinates': {'latitude': 31.24897, 'longitude': 35.21597},
#   'country': 'IL',
#   'sourceName': 'Israel',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T05:00:00.000Z',
#    'local': '2017-12-31T07:00:00+02:00'},
#   'parameter': 'o3',
#   'location': 'תחנה:ניידת חיפה',
#   'value': 0.0359,
#   'unit': 'ppm',
#   'city': 'צפון הנגב',
#   'attribution': [{'name': 'Israel Ministry of Environmental Protection',
#     'url': 'http://www.svivaaqm.net/'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 0.25},
#   'coordinates': {'latitude': 31.24897, 'longitude': 35.21597},
#   'country': 'IL',
#   'sourceName': 'Israel',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T05:15:00.000Z',
#    'local': '2017-12-31T07:15:00+02:00'},
#   'parameter': 'o3',
#   'location': 'תחנה:ניידת חיפה',
#   'value': 0.0364,
#   'unit': 'ppm',
#   'city': 'צפון הנגב',
#   'attribution': [{'name': 'Israel Ministry of Environmental Protection',
#     'url': 'http://www.svivaaqm.net/'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 0.25},
#   'coordinates': {'latitude': 31.24897, 'longitude': 35.21597},
#   'country': 'IL',
#   'sourceName': 'Israel',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T05:30:00.000Z',
#    'local': '2017-12-31T07:30:00+02:00'},
#   'parameter': 'o3',
#   'location': 'תחנה:ניידת חיפה',
#   'value': 0.036,
#   'unit': 'ppm',
#   'city': 'צפון הנגב',
#   'attribution': [{'name': 'Israel Ministry of Environmental Protection',
#     'url': 'http://www.svivaaqm.net/'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 0.25},
#   'coordinates': {'latitude': 31.24897, 'longitude': 35.21597},
#   'country': 'IL',
#   'sourceName': 'Israel',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T05:45:00.000Z',
#    'local': '2017-12-31T07:45:00+02:00'},
#   'parameter': 'o3',
#   'location': 'תחנה:ניידת חיפה',
#   'value': 0.0359,
#   'unit': 'ppm',
#   'city': 'צפון הנגב',
#   'attribution': [{'name': 'Israel Ministry of Environmental Protection',
#     'url': 'http://www.svivaaqm.net/'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 0.25},
#   'coordinates': {'latitude': 31.24897, 'longitude': 35.21597},
#   'country': 'IL',
#   'sourceName': 'Israel',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T06:00:00.000Z',
#    'local': '2017-12-31T08:00:00+02:00'},
#   'parameter': 'o3',
#   'location': 'תחנה:ניידת חיפה',
#   'value': 0.037200000000000004,
#   'unit': 'ppm',
#   'city': 'צפון הנגב',
#   'attribution': [{'name': 'Israel Ministry of Environmental Protection',
#     'url': 'http://www.svivaaqm.net/'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 0.25},
#   'coordinates': {'latitude': 31.24897, 'longitude': 35.21597},
#   'country': 'IL',
#   'sourceName': 'Israel',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T06:15:00.000Z',
#    'local': '2017-12-31T08:15:00+02:00'},
#   'parameter': 'o3',
#   'location': 'תחנה:ניידת חיפה',
#   'value': 0.0344,
#   'unit': 'ppm',
#   'city': 'צפון הנגב',
#   'attribution': [{'name': 'Israel Ministry of Environmental Protection',
#     'url': 'http://www.svivaaqm.net/'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 0.25},
#   'coordinates': {'latitude': 31.24897, 'longitude': 35.21597},
#   'country': 'IL',
#   'sourceName': 'Israel',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T06:30:00.000Z',
#    'local': '2017-12-31T08:30:00+02:00'},
#   'parameter': 'o3',
#   'location': 'תחנה:ניידת חיפה',
#   'value': 0.0353,
#   'unit': 'ppm',
#   'city': 'צפון הנגב',
#   'attribution': [{'name': 'Israel Ministry of Environmental Protection',
#     'url': 'http://www.svivaaqm.net/'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 0.25},
#   'coordinates': {'latitude': 31.24897, 'longitude': 35.21597},
#   'country': 'IL',
#   'sourceName': 'Israel',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T06:45:00.000Z',
#    'local': '2017-12-31T08:45:00+02:00'},
#   'parameter': 'o3',
#   'location': 'תחנה:ניידת חיפה',
#   'value': 0.037399999999999996,
#   'unit': 'ppm',
#   'city': 'צפון הנגב',
#   'attribution': [{'name': 'Israel Ministry of Environmental Protection',
#     'url': 'http://www.svivaaqm.net/'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 0.25},
#   'coordinates': {'latitude': 31.24897, 'longitude': 35.21597},
#   'country': 'IL',
#   'sourceName': 'Israel',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T07:00:00.000Z',
#    'local': '2017-12-31T09:00:00+02:00'},
#   'parameter': 'o3',
#   'location': 'תחנה:ניידת חיפה',
#   'value': 0.037700000000000004,
#   'unit': 'ppm',
#   'city': 'צפון הנגב',
#   'attribution': [{'name': 'Israel Ministry of Environmental Protection',
#     'url': 'http://www.svivaaqm.net/'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 0.25},
#   'coordinates': {'latitude': 31.24897, 'longitude': 35.21597},
#   'country': 'IL',
#   'sourceName': 'Israel',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T07:15:00.000Z',
#    'local': '2017-12-31T09:15:00+02:00'},
#   'parameter': 'o3',
#   'location': 'תחנה:ניידת חיפה',
#   'value': 0.0293,
#   'unit': 'ppm',
#   'city': 'צפון הנגב',
#   'attribution': [{'name': 'Israel Ministry of Environmental Protection',
#     'url': 'http://www.svivaaqm.net/'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 0.25},
#   'coordinates': {'latitude': 31.24897, 'longitude': 35.21597},
#   'country': 'IL',
#   'sourceName': 'Israel',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T07:30:00.000Z',
#    'local': '2017-12-31T09:30:00+02:00'},
#   'parameter': 'o3',
#   'location': 'תחנה:ניידת חיפה',
#   'value': 0.0376,
#   'unit': 'ppm',
#   'city': 'צפון הנגב',
#   'attribution': [{'name': 'Israel Ministry of Environmental Protection',
#     'url': 'http://www.svivaaqm.net/'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 0.25},
#   'coordinates': {'latitude': 31.24897, 'longitude': 35.21597},
#   'country': 'IL',
#   'sourceName': 'Israel',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T07:45:00.000Z',
#    'local': '2017-12-31T09:45:00+02:00'},
#   'parameter': 'o3',
#   'location': 'תחנה:ניידת חיפה',
#   'value': 0.04,
#   'unit': 'ppm',
#   'city': 'צפון הנגב',
#   'attribution': [{'name': 'Israel Ministry of Environmental Protection',
#     'url': 'http://www.svivaaqm.net/'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 0.25},
#   'coordinates': {'latitude': 31.24897, 'longitude': 35.21597},
#   'country': 'IL',
#   'sourceName': 'Israel',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T08:00:00.000Z',
#    'local': '2017-12-31T10:00:00+02:00'},
#   'parameter': 'o3',
#   'location': 'תחנה:ניידת חיפה',
#   'value': 0.0412,
#   'unit': 'ppm',
#   'city': 'צפון הנגב',
#   'attribution': [{'name': 'Israel Ministry of Environmental Protection',
#     'url': 'http://www.svivaaqm.net/'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 0.25},
#   'coordinates': {'latitude': 31.24897, 'longitude': 35.21597},
#   'country': 'IL',
#   'sourceName': 'Israel',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T08:15:00.000Z',
#    'local': '2017-12-31T10:15:00+02:00'},
#   'parameter': 'o3',
#   'location': 'תחנה:ניידת חיפה',
#   'value': 0.041100000000000005,
#   'unit': 'ppm',
#   'city': 'צפון הנגב',
#   'attribution': [{'name': 'Israel Ministry of Environmental Protection',
#     'url': 'http://www.svivaaqm.net/'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 0.25},
#   'coordinates': {'latitude': 31.24897, 'longitude': 35.21597},
#   'country': 'IL',
#   'sourceName': 'Israel',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T08:30:00.000Z',
#    'local': '2017-12-31T10:30:00+02:00'},
#   'parameter': 'o3',
#   'location': 'תחנה:ניידת חיפה',
#   'value': 0.045399999999999996,
#   'unit': 'ppm',
#   'city': 'צפון הנגב',
#   'attribution': [{'name': 'Israel Ministry of Environmental Protection',
#     'url': 'http://www.svivaaqm.net/'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 0.25},
#   'coordinates': {'latitude': 31.24897, 'longitude': 35.21597},
#   'country': 'IL',
#   'sourceName': 'Israel',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T08:45:00.000Z',
#    'local': '2017-12-31T10:45:00+02:00'},
#   'parameter': 'o3',
#   'location': 'תחנה:ניידת חיפה',
#   'value': 0.0465,
#   'unit': 'ppm',
#   'city': 'צפון הנגב',
#   'attribution': [{'name': 'Israel Ministry of Environmental Protection',
#     'url': 'http://www.svivaaqm.net/'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 0.25},
#   'coordinates': {'latitude': 31.24897, 'longitude': 35.21597},
#   'country': 'IL',
#   'sourceName': 'Israel',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T09:00:00.000Z',
#    'local': '2017-12-31T11:00:00+02:00'},
#   'parameter': 'o3',
#   'location': 'תחנה:ניידת חיפה',
#   'value': 0.0451,
#   'unit': 'ppm',
#   'city': 'צפון הנגב',
#   'attribution': [{'name': 'Israel Ministry of Environmental Protection',
#     'url': 'http://www.svivaaqm.net/'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 0.25},
#   'coordinates': {'latitude': 31.24897, 'longitude': 35.21597},
#   'country': 'IL',
#   'sourceName': 'Israel',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T09:15:00.000Z',
#    'local': '2017-12-31T11:15:00+02:00'},
#   'parameter': 'o3',
#   'location': 'תחנה:ניידת חיפה',
#   'value': 0.044899999999999995,
#   'unit': 'ppm',
#   'city': 'צפון הנגב',
#   'attribution': [{'name': 'Israel Ministry of Environmental Protection',
#     'url': 'http://www.svivaaqm.net/'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 0.25},
#   'coordinates': {'latitude': 31.24897, 'longitude': 35.21597},
#   'country': 'IL',
#   'sourceName': 'Israel',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T09:30:00.000Z',
#    'local': '2017-12-31T11:30:00+02:00'},
#   'parameter': 'o3',
#   'location': 'תחנה:ניידת חיפה',
#   'value': 0.0448,
#   'unit': 'ppm',
#   'city': 'צפון הנגב',
#   'attribution': [{'name': 'Israel Ministry of Environmental Protection',
#     'url': 'http://www.svivaaqm.net/'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 0.25},
#   'coordinates': {'latitude': 31.24897, 'longitude': 35.21597},
#   'country': 'IL',
#   'sourceName': 'Israel',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T09:45:00.000Z',
#    'local': '2017-12-31T11:45:00+02:00'},
#   'parameter': 'o3',
#   'location': 'תחנה:ניידת חיפה',
#   'value': 0.047799999999999995,
#   'unit': 'ppm',
#   'city': 'צפון הנגב',
#   'attribution': [{'name': 'Israel Ministry of Environmental Protection',
#     'url': 'http://www.svivaaqm.net/'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 0.25},
#   'coordinates': {'latitude': 31.24897, 'longitude': 35.21597},
#   'country': 'IL',
#   'sourceName': 'Israel',
#   'sourceType': 'government',
#   'mobile': False},
#  {'date': {'utc': '2017-12-31T10:00:00.000Z',
#    'local': '2017-12-31T12:00:00+02:00'},
#   'parameter': 'o3',
#   'location': 'תחנה:ניידת חיפה',
#   'value': 0.048799999999999996,
#   'unit': 'ppm',
#   'city': 'צפון הנגב',
#   'attribution': [{'name': 'Israel Ministry of Environmental Protection',
#     'url': 'http://www.svivaaqm.net/'}],
#   'averagingPeriod': {'unit': 'hours', 'value': 0.25},
#   'coordinates': {'latitude': 31.24897, 'longitude': 35.21597},
#   'country': 'IL',
#   'sourceName': 'Israel',
#   'sourceType': 'government',
#   'mobile': False},
#  ...]

# %%
### mind the slice here, only first 20 records for testing
for key in tqdm_notebook(keys[:20]):
    key = key.strip()
    print(f'Processing: {key}')
    mes = get_relevant_measurements(key, lambda x: x['country']=='DE')
    if len(mes) ==0:
        continue
    print(f"Nr of relevant mes: {len(mes)}")
    write_down(key, mes)
# Out:
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# Processing: realtime-gzipped/2018-01-01/1514765764.ndjson.gz
# Processing: realtime-gzipped/2018-01-01/1514766350.ndjson.gz
# Processing: realtime-gzipped/2018-01-01/1514767062.ndjson.gz
# Processing: realtime-gzipped/2018-01-01/1514767560.ndjson.gz
# Processing: realtime-gzipped/2018-01-01/1514768252.ndjson.gz
# Processing: realtime-gzipped/2018-01-01/1514768946.ndjson.gz
# Processing: realtime-gzipped/2018-01-01/1514771223.ndjson.gz
# Processing: realtime-gzipped/2018-01-01/1514771782.ndjson.gz
# Processing: realtime-gzipped/2018-01-01/1514772927.ndjson.gz
# Processing: realtime-gzipped/2018-01-01/1514773597.ndjson.gz
# Processing: realtime-gzipped/2018-01-01/1514774820.ndjson.gz
# Processing: realtime-gzipped/2018-01-01/1514776113.ndjson.gz
# Processing: realtime-gzipped/2018-01-01/1514776534.ndjson.gz
# Processing: realtime-gzipped/2018-01-01/1514777898.ndjson.gz
# Processing: realtime-gzipped/2018-01-01/1514778404.ndjson.gz
# Processing: realtime-gzipped/2018-01-01/1514781516.ndjson.gz
# Processing: realtime-gzipped/2018-01-01/1514783393.ndjson.gz
# Processing: realtime-gzipped/2018-01-01/1514783742.ndjson.gz
# Processing: realtime-gzipped/2018-01-01/1514790882.ndjson.gz
# Nr of relevant mes: 7395
# Processing: realtime-gzipped/2018-01-01/1514791644.ndjson.gz
# Nr of relevant mes: 27

# %%
# In case you want to speed up things, but check first
import concurrent.futures

with concurrent.futures.ThreadPoolExecutor(max_workers=None) as executor:
        future_measurements = {executor.submit(get_relevant_measurements, prefix.strip()): prefix for prefix in keys}
        
        for future in concurrent.futures.as_completed(future_measurements):
            url = future_measurements[future]
            try:
                data = future.result()
            except Exception as exc:
                logging.error('%r generated an exception: %s' % (url, exc))
            else:
                write_down(url, data)
# Out:
# Empty...
# Empty...
# Empty...
# Empty...
# Empty...

# %%
! ls -altr /tmp/ex
# Out:
# total 660
# -rw-rw-r--  1 jj   jj   138327 Oct 30 11:05 tes.csv
# drwxrwxr-x  2 jj   jj    20480 Oct 30 11:57 .
# drwxrwxrwt 22 root root  40960 Oct 30 12:42 ..
# -rw-rw-r--  1 jj   jj   459243 Oct 30 12:47 realtime-gzipped-2018-01-01-1514790882.ndjson.gz.csv
# -rw-rw-r--  1 jj   jj     1702 Oct 30 12:47 realtime-gzipped-2018-01-01-1514791644.ndjson.gz.csv
